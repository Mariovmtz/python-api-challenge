# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observable trends in data:
#
# 1. Temperature increases the closer the city is to latitude 0 and decreases the further away.
# 2. Cities near latitude 0 are less dry
# 3. Few cities have a wind speed higher than 25 mph

# %%
# Dependencies and Setup
import json
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

outputDirectory = "output_data"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
counter = 0
max_cities = len(cities) - 1
weather_url = "http://api.openweathermap.org/data/2.5/weather?"
cities_df = pd.DataFrame(columns=['Name','Cloudiness','Country','Date','Humidity',
                                  'Lat','Lng','Max Temp','Wind Speed'])


#
print(f"Beginning Data Retrieval")
print(f"----------------------------------")
#


for city in cities:
      
    query_url = weather_url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
    response = requests.get(query_url)
    res_json = response.json()
    response_code = res_json.get("cod")

    if response_code == 200:
    
        print(f"Processing city {counter} of {max_cities}, name: {city.capitalize()}")
    
        cities_df = cities_df.append({'Name': res_json["name"],
                                      'Cloudiness': res_json["clouds"]["all"],
                                      'Country': res_json["sys"]["country"],
                                      'Date': res_json["dt"],
                                      'Humidity': res_json["main"]["humidity"],
                                      'Lat': res_json["coord"]["lat"],
                                      'Lng': res_json["coord"]["lon"],
                                      'Max Temp': res_json["main"]["temp_max"],
                                      'Wind Speed': res_json["wind"]["speed"]
                                     }, ignore_index = True)
        
    else:
        print(f"The city {city.capitalize()} could not be found, skipping city...")
        
    counter += 1
# Out:
# Beginning Data Retrieval
# ----------------------------------
# The city Belushya guba could not be found, skipping city...
# Processing city 1 of 597, name: Sakakah
# The city Sulurpeta could not be found, skipping city...
# Processing city 3 of 597, name: Milkovo
# Processing city 4 of 597, name: Puri
# Processing city 5 of 597, name: Fayaoue
# Processing city 6 of 597, name: Phangnga
# Processing city 7 of 597, name: Busselton
# Processing city 8 of 597, name: Mataura
# The city Illoqqortoormiut could not be found, skipping city...
# The city Katsiveli could not be found, skipping city...
# Processing city 11 of 597, name: Gat
# Processing city 12 of 597, name: Hermanus
# The city Vaitupu could not be found, skipping city...
# Processing city 14 of 597, name: Jamestown
# Processing city 15 of 597, name: Qovlar
# Processing city 16 of 597, name: Rikitea
# Processing city 17 of 597, name: Ixtapa
# Processing city 18 of 597, name: Jiazi
# Processing city 19 of 597, name: Ushuaia
# Processing city 20 of 597, name: Abu kamal
# Processing city 21 of 597, name: Saint george
# Processing city 22 of 597, name: Ust-kuyga
# The city Grand river south east could not be found, skipping city...
# Processing city 24 of 597, name: Vitim
# Processing city 25 of 597, name: Nuuk
# Processing city 26 of 597, name: Kassala
# Processing city 27 of 597, name: Kavieng
# Processing city 28 of 597, name: Clyde river
# Processing city 29 of 597, name: Port alfred
# Processing city 30 of 597, name: Sur
# Processing city 31 of 597, name: Iskateley
# Processing city 32 of 597, name: Alofi
# Processing city 33 of 597, name: Narsaq
# Processing city 34 of 597, name: Palu
# Processing city 35 of 597, name: Lata
# Processing city 36 of 597, name: Jalu
# Processing city 37 of 597, name: Ahipara
# Processing city 38 of 597, name: Rio brilhante
# Processing city 39 of 597, name: Rajpipla
# The city Amderma could not be found, skipping city...
# Processing city 41 of 597, name: Atuona
# Processing city 42 of 597, name: Meulaboh
# The city Chagda could not be found, skipping city...
# Processing city 44 of 597, name: Dunedin
# Processing city 45 of 597, name: Klaksvik
# Processing city 46 of 597, name: Tepusteca
# Processing city 47 of 597, name: Carnarvon
# Processing city 48 of 597, name: Srednekolymsk
# Processing city 49 of 597, name: Arraial do cabo
# Processing city 50 of 597, name: Cape town
# Processing city 51 of 597, name: Bredasdorp
# Processing city 52 of 597, name: Ewa beach
# Processing city 53 of 597, name: Port lincoln
# Processing city 54 of 597, name: Anadyr
# Processing city 55 of 597, name: Gainesville
# Processing city 56 of 597, name: Constitucion
# Processing city 57 of 597, name: Kaitangata
# Processing city 58 of 597, name: Touros
# Processing city 59 of 597, name: Saskylakh
# Processing city 60 of 597, name: Alugan
# Processing city 61 of 597, name: Punta arenas
# Processing city 62 of 597, name: Oyama
# Processing city 63 of 597, name: Airai
# Processing city 64 of 597, name: Naze
# Processing city 65 of 597, name: Portland
# Processing city 66 of 597, name: Sitka
# Processing city 67 of 597, name: Namibe
# Processing city 68 of 597, name: New norfolk
# Processing city 69 of 597, name: Isangel
# Processing city 70 of 597, name: Boffa
# Processing city 71 of 597, name: Yellowknife
# Processing city 72 of 597, name: Chuy
# Processing city 73 of 597, name: Vaini
# Processing city 74 of 597, name: Kruisfontein
# Processing city 75 of 597, name: Eydhafushi
# Processing city 76 of 597, name: Butaritari
# Processing city 77 of 597, name: Pevek
# Processing city 78 of 597, name: Yumen
# Processing city 79 of 597, name: Hilo
# Processing city 80 of 597, name: Port hardy
# Processing city 81 of 597, name: Magdagachi
# Processing city 82 of 597, name: Kristiansund
# Processing city 83 of 597, name: Moerai
# Processing city 84 of 597, name: Hithadhoo
# Processing city 85 of 597, name: Salalah
# Processing city 86 of 597, name: Cidreira
# Processing city 87 of 597, name: Collie
# Processing city 88 of 597, name: Tandil
# Processing city 89 of 597, name: Kahului
# Processing city 90 of 597, name: Codrington
# Processing city 91 of 597, name: Ruteng
# Processing city 92 of 597, name: Prainha
# Processing city 93 of 597, name: Mahebourg
# The city Nylstroom could not be found, skipping city...
# Processing city 95 of 597, name: Avarua
# Processing city 96 of 597, name: Saint-augustin
# Processing city 97 of 597, name: Albany
# The city Taolanaro could not be found, skipping city...
# Processing city 99 of 597, name: Talnakh
# Processing city 100 of 597, name: Mar del plata
# Processing city 101 of 597, name: Barrow
# Processing city 102 of 597, name: Qasigiannguit
# Processing city 103 of 597, name: Berlevag
# Processing city 104 of 597, name: Bethel
# Processing city 105 of 597, name: Qaanaaq
# The city Tsihombe could not be found, skipping city...
# Processing city 107 of 597, name: Saint-louis
# Processing city 108 of 597, name: Kosonsoy
# Processing city 109 of 597, name: Nipawin
# Processing city 110 of 597, name: Yerbogachen
# Processing city 111 of 597, name: Beringovskiy
# The city Tumannyy could not be found, skipping city...
# The city Inderborskiy could not be found, skipping city...
# Processing city 114 of 597, name: Tuktoyaktuk
# Processing city 115 of 597, name: Vila velha
# Processing city 116 of 597, name: Watrous
# Processing city 117 of 597, name: Nanortalik
# The city Mys shmidta could not be found, skipping city...
# Processing city 119 of 597, name: Ponta do sol
# Processing city 120 of 597, name: Lavrentiya
# Processing city 121 of 597, name: Saint-georges
# Processing city 122 of 597, name: Cayenne
# Processing city 123 of 597, name: Bayan
# Processing city 124 of 597, name: Pangody
# Processing city 125 of 597, name: Karratha
# Processing city 126 of 597, name: Sisimiut
# Processing city 127 of 597, name: Bilma
# The city Samusu could not be found, skipping city...
# Processing city 129 of 597, name: Teguise
# Processing city 130 of 597, name: Sao geraldo do araguaia
# Processing city 131 of 597, name: Kapaa
# Processing city 132 of 597, name: Quelimane
# Processing city 133 of 597, name: Sao felix do xingu
# Processing city 134 of 597, name: Lebu
# The city Kamenskoye could not be found, skipping city...
# Processing city 136 of 597, name: Mahibadhoo
# Processing city 137 of 597, name: Georgetown
# Processing city 138 of 597, name: Gloversville
# Processing city 139 of 597, name: Cherskiy
# Processing city 140 of 597, name: Lompoc
# Processing city 141 of 597, name: Bluff
# The city Khonuu could not be found, skipping city...
# Processing city 143 of 597, name: Fortuna
# Processing city 144 of 597, name: Aracuai
# Processing city 145 of 597, name: Arman
# The city Attawapiskat could not be found, skipping city...
# Processing city 147 of 597, name: Lorengau
# Processing city 148 of 597, name: Mehran
# Processing city 149 of 597, name: Pacific grove
# Processing city 150 of 597, name: Paamiut
# Processing city 151 of 597, name: Faya
# Processing city 152 of 597, name: Armenia
# Processing city 153 of 597, name: East london
# Processing city 154 of 597, name: Kirakira
# Processing city 155 of 597, name: Corinth
# Processing city 156 of 597, name: Chabahar
# Processing city 157 of 597, name: Paita
# Processing city 158 of 597, name: Antofagasta
# Processing city 159 of 597, name: Faanui
# Processing city 160 of 597, name: Northam
# Processing city 161 of 597, name: Ayaviri
# The city Barentsburg could not be found, skipping city...
# Processing city 163 of 597, name: Prince rupert
# Processing city 164 of 597, name: Praia da vitoria
# Processing city 165 of 597, name: Pucallpa
# Processing city 166 of 597, name: Tezu
# Processing city 167 of 597, name: Severo-kurilsk
# Processing city 168 of 597, name: Labrea
# Processing city 169 of 597, name: Niigata
# Processing city 170 of 597, name: Victoria
# Processing city 171 of 597, name: Ancud
# Processing city 172 of 597, name: Luderitz
# Processing city 173 of 597, name: Bathsheba
# Processing city 174 of 597, name: Avera
# Processing city 175 of 597, name: Qurayyat
# Processing city 176 of 597, name: Ostersund
# Processing city 177 of 597, name: Tiksi
# The city Samalaeulu could not be found, skipping city...
# Processing city 179 of 597, name: Fare
# Processing city 180 of 597, name: Kvarkeno
# Processing city 181 of 597, name: Necochea
# Processing city 182 of 597, name: Senneterre
# Processing city 183 of 597, name: Sibiti
# Processing city 184 of 597, name: Tasiilaq
# Processing city 185 of 597, name: Khatanga
# Processing city 186 of 597, name: Korla
# Processing city 187 of 597, name: Amahai
# Processing city 188 of 597, name: Norman wells
# Processing city 189 of 597, name: Coquimbo
# Processing city 190 of 597, name: Kodiak
# Processing city 191 of 597, name: Barnsley
# The city Louisbourg could not be found, skipping city...
# Processing city 193 of 597, name: Castro
# Processing city 194 of 597, name: Cabedelo
# Processing city 195 of 597, name: Artesia
# Processing city 196 of 597, name: Maputo
# Processing city 197 of 597, name: Coihaique
# The city Ngukurr could not be found, skipping city...
# Processing city 199 of 597, name: Leningradskiy
# Processing city 200 of 597, name: High rock
# Processing city 201 of 597, name: Thyboron
# Processing city 202 of 597, name: Bilibino
# Processing city 203 of 597, name: Guerrero negro
# Processing city 204 of 597, name: Kiwira
# Processing city 205 of 597, name: Bengkulu
# Processing city 206 of 597, name: Grindavik
# Processing city 207 of 597, name: Thompson
# Processing city 208 of 597, name: Parry sound
# Processing city 209 of 597, name: Souillac
# Processing city 210 of 597, name: Puerto ayora
# Processing city 211 of 597, name: French harbor
# Processing city 212 of 597, name: Hobart
# Processing city 213 of 597, name: Mount gambier
# Processing city 214 of 597, name: Ilulissat
# Processing city 215 of 597, name: Hermiston
# Processing city 216 of 597, name: Kaeo
# Processing city 217 of 597, name: Geraldton
# Processing city 218 of 597, name: Horsham
# Processing city 219 of 597, name: Cap malheureux
# Processing city 220 of 597, name: Algeciras
# Processing city 221 of 597, name: Nantucket
# Processing city 222 of 597, name: Peniche
# Processing city 223 of 597, name: Ambon
# Processing city 224 of 597, name: Bubaque
# Processing city 225 of 597, name: Hualmay
# Processing city 226 of 597, name: Zarechnyy
# The city Yialos could not be found, skipping city...
# Processing city 228 of 597, name: Texarkana
# Processing city 229 of 597, name: Gushikawa
# Processing city 230 of 597, name: Xiongzhou
# Processing city 231 of 597, name: San patricio
# Processing city 232 of 597, name: Xuanhua
# Processing city 233 of 597, name: Makakilo city
# Processing city 234 of 597, name: Provideniya
# Processing city 235 of 597, name: Sao filipe
# Processing city 236 of 597, name: Bodden town
# Processing city 237 of 597, name: Tilichiki
# Processing city 238 of 597, name: Raudeberg
# Processing city 239 of 597, name: Mandurah
# Processing city 240 of 597, name: Panguna
# Processing city 241 of 597, name: Husavik
# Processing city 242 of 597, name: Campos sales
# Processing city 243 of 597, name: Bijapur
# Processing city 244 of 597, name: Alice springs
# Processing city 245 of 597, name: Dikson
# Processing city 246 of 597, name: Two rivers
# Processing city 247 of 597, name: Tucurui
# Processing city 248 of 597, name: Acapulco
# Processing city 249 of 597, name: Morondava
# Processing city 250 of 597, name: Mumford
# Processing city 251 of 597, name: Hlotse
# Processing city 252 of 597, name: Akdepe
# Processing city 253 of 597, name: Batagay
# Processing city 254 of 597, name: Fort-shevchenko
# Processing city 255 of 597, name: Imbituba
# Processing city 256 of 597, name: Ahuimanu
# Processing city 257 of 597, name: Pasighat
# Processing city 258 of 597, name: Port elizabeth
# Processing city 259 of 597, name: Hasanabad
# Processing city 260 of 597, name: Penzance
# Processing city 261 of 597, name: Saint-philippe
# Processing city 262 of 597, name: Palana
# Processing city 263 of 597, name: Lingao
# Processing city 264 of 597, name: Torbay
# Processing city 265 of 597, name: Turan
# Processing city 266 of 597, name: Chokurdakh
# The city Nizhneyansk could not be found, skipping city...
# Processing city 268 of 597, name: Te anau
# Processing city 269 of 597, name: San remo
# Processing city 270 of 597, name: Esperance
# Processing city 271 of 597, name: Yulara
# Processing city 272 of 597, name: Caravelas
# Processing city 273 of 597, name: Sorrento
# Processing city 274 of 597, name: Longyearbyen
# Processing city 275 of 597, name: Noumea
# Processing city 276 of 597, name: Kyzyl-suu
# Processing city 277 of 597, name: Gatesville
# Processing city 278 of 597, name: Katsuura
# Processing city 279 of 597, name: Santo angelo
# Processing city 280 of 597, name: Sehore
# Processing city 281 of 597, name: Nemuro
# The city Nguiu could not be found, skipping city...
# Processing city 283 of 597, name: Aswan
# Processing city 284 of 597, name: Kupang
# The city Lolua could not be found, skipping city...
# Processing city 286 of 597, name: Prata
# Processing city 287 of 597, name: Ishigaki
# Processing city 288 of 597, name: Jalingo
# Processing city 289 of 597, name: Padang
# Processing city 290 of 597, name: Ofaqim
# Processing city 291 of 597, name: Waipawa
# Processing city 292 of 597, name: Thai binh
# Processing city 293 of 597, name: Queanbeyan
# Processing city 294 of 597, name: Warman
# Processing city 295 of 597, name: Apache junction
# Processing city 296 of 597, name: Healdsburg
# Processing city 297 of 597, name: Vanimo
# Processing city 298 of 597, name: Tuatapere
# Processing city 299 of 597, name: Bradford
# Processing city 300 of 597, name: Mogadishu
# Processing city 301 of 597, name: Rafraf
# Processing city 302 of 597, name: Saint anthony
# Processing city 303 of 597, name: Flinders
# Processing city 304 of 597, name: Mbaiki
# Processing city 305 of 597, name: Takhtamygda
# Processing city 306 of 597, name: Manggar
# Processing city 307 of 597, name: Adrar
# Processing city 308 of 597, name: Tommot
# The city Saleaula could not be found, skipping city...
# Processing city 310 of 597, name: Hohhot
# Processing city 311 of 597, name: Chilca
# Processing city 312 of 597, name: Mount isa
# Processing city 313 of 597, name: Ostrovnoy
# Processing city 314 of 597, name: The valley
# The city Ruatoria could not be found, skipping city...
# Processing city 316 of 597, name: Boende
# Processing city 317 of 597, name: Quepos
# Processing city 318 of 597, name: Ngorongoro
# Processing city 319 of 597, name: Saldanha
# Processing city 320 of 597, name: Broome
# Processing city 321 of 597, name: Aguimes
# Processing city 322 of 597, name: Ibipeba
# Processing city 323 of 597, name: Takoradi
# Processing city 324 of 597, name: Mayor pablo lagerenza
# Processing city 325 of 597, name: Xuddur
# Processing city 326 of 597, name: La romana
# Processing city 327 of 597, name: Kununurra
# Processing city 328 of 597, name: Powell river
# Processing city 329 of 597, name: Ornskoldsvik
# The city Ust-kamchatsk could not be found, skipping city...
# Processing city 331 of 597, name: Waddan
# Processing city 332 of 597, name: Port augusta
# Processing city 333 of 597, name: Walvis bay
# Processing city 334 of 597, name: Kalmunai
# Processing city 335 of 597, name: Backa palanka
# Processing city 336 of 597, name: Kamsack
# Processing city 337 of 597, name: Tabora
# Processing city 338 of 597, name: Aklavik
# Processing city 339 of 597, name: Kyshtovka
# Processing city 340 of 597, name: Tazovskiy
# Processing city 341 of 597, name: Isla vista
# Processing city 342 of 597, name: Bartica
# Processing city 343 of 597, name: Huntsville
# Processing city 344 of 597, name: Labuhan
# Processing city 345 of 597, name: Hobyo
# Processing city 346 of 597, name: Waitati
# Processing city 347 of 597, name: Sfantu gheorghe
# Processing city 348 of 597, name: Riyadh
# Processing city 349 of 597, name: Dingli
# Processing city 350 of 597, name: San cristobal
# Processing city 351 of 597, name: Dalvik
# Processing city 352 of 597, name: Cascais
# Processing city 353 of 597, name: Borogontsy
# Processing city 354 of 597, name: Le port
# Processing city 355 of 597, name: Ambilobe
# Processing city 356 of 597, name: Rawson
# Processing city 357 of 597, name: Shimoda
# Processing city 358 of 597, name: Iqaluit
# Processing city 359 of 597, name: Kawalu
# Processing city 360 of 597, name: Atherton
# The city Palabuhanratu could not be found, skipping city...
# Processing city 362 of 597, name: Valparaiso
# Processing city 363 of 597, name: Laibin
# Processing city 364 of 597, name: Richards bay
# Processing city 365 of 597, name: Abu zabad
# Processing city 366 of 597, name: Dunmore east
# Processing city 367 of 597, name: Upernavik
# Processing city 368 of 597, name: Ghanzi
# Processing city 369 of 597, name: Namatanai
# Processing city 370 of 597, name: Saint-leu
# Processing city 371 of 597, name: Olinda
# Processing city 372 of 597, name: Yatou
# Processing city 373 of 597, name: Bentiu
# Processing city 374 of 597, name: Maldonado
# Processing city 375 of 597, name: Nabire
# Processing city 376 of 597, name: Jhinjhak
# Processing city 377 of 597, name: Oktyabrskiy
# Processing city 378 of 597, name: Ribeira grande
# Processing city 379 of 597, name: San quintin
# Processing city 380 of 597, name: Salinas
# Processing city 381 of 597, name: San rafael
# Processing city 382 of 597, name: Nelson bay
# Processing city 383 of 597, name: Chapais
# Processing city 384 of 597, name: Darhan
# Processing city 385 of 597, name: Shenjiamen
# Processing city 386 of 597, name: Cap-aux-meules
# Processing city 387 of 597, name: Vanavara
# Processing city 388 of 597, name: Severnoye
# Processing city 389 of 597, name: Beisfjord
# Processing city 390 of 597, name: Chala
# Processing city 391 of 597, name: Champerico
# The city Tidore could not be found, skipping city...
# Processing city 393 of 597, name: Bambous virieux
# Processing city 394 of 597, name: Salym
# Processing city 395 of 597, name: Sorland
# Processing city 396 of 597, name: Kasongo-lunda
# Processing city 397 of 597, name: Methoni
# Processing city 398 of 597, name: Kulu
# Processing city 399 of 597, name: Sandomierz
# Processing city 400 of 597, name: Puro
# Processing city 401 of 597, name: Skjervoy
# Processing city 402 of 597, name: Fairbanks
# Processing city 403 of 597, name: Serowe
# Processing city 404 of 597, name: Port-gentil
# Processing city 405 of 597, name: Paracuru
# Processing city 406 of 597, name: Kenai
# Processing city 407 of 597, name: Yarim
# Processing city 408 of 597, name: Virginia beach
# Processing city 409 of 597, name: Aykhal
# The city Cheuskiny could not be found, skipping city...
# Processing city 411 of 597, name: Baykalsk
# Processing city 412 of 597, name: Pontiac
# Processing city 413 of 597, name: Luwuk
# The city Marcona could not be found, skipping city...
# Processing city 415 of 597, name: Bairiki
# Processing city 416 of 597, name: Blagoyevo
# Processing city 417 of 597, name: Alihe
# Processing city 418 of 597, name: Panzhihua
# Processing city 419 of 597, name: Prosperous
# Processing city 420 of 597, name: Treinta y tres
# The city Halalo could not be found, skipping city...
# Processing city 422 of 597, name: Corner brook
# Processing city 423 of 597, name: Risor
# Processing city 424 of 597, name: Marawi
# Processing city 425 of 597, name: Hambantota
# Processing city 426 of 597, name: Maningrida
# Processing city 427 of 597, name: Huaihua
# Processing city 428 of 597, name: Santa cruz
# Processing city 429 of 597, name: Lasa
# Processing city 430 of 597, name: Kovdor
# Processing city 431 of 597, name: Belmonte
# Processing city 432 of 597, name: Buala
# Processing city 433 of 597, name: Hongjiang
# Processing city 434 of 597, name: Samarai
# Processing city 435 of 597, name: Nizwa
# Processing city 436 of 597, name: Nikolskoye
# Processing city 437 of 597, name: Sotouboua
# The city Cockburn harbour could not be found, skipping city...
# Processing city 439 of 597, name: Jimani
# Processing city 440 of 597, name: High level
# Processing city 441 of 597, name: Kang
# Processing city 442 of 597, name: Sao gabriel da cachoeira
# Processing city 443 of 597, name: May pen
# Processing city 444 of 597, name: Salinopolis
# Processing city 445 of 597, name: Santa maria
# The city Labutta could not be found, skipping city...
# Processing city 447 of 597, name: Pisco
# Processing city 448 of 597, name: Wanganui
# Processing city 449 of 597, name: Maneadero
# Processing city 450 of 597, name: Shahdadkot
# Processing city 451 of 597, name: Acoyapa
# Processing city 452 of 597, name: Wajima
# Processing city 453 of 597, name: Zyryanka
# Processing city 454 of 597, name: Maniwaki
# The city Sentyabrskiy could not be found, skipping city...
# Processing city 456 of 597, name: Komsomolskiy
# Processing city 457 of 597, name: Wairoa
# Processing city 458 of 597, name: Estelle
# Processing city 459 of 597, name: Mount pleasant
# Processing city 460 of 597, name: Stanghelle
# Processing city 461 of 597, name: Nola
# Processing city 462 of 597, name: Shanghai
# Processing city 463 of 597, name: Kolokani
# Processing city 464 of 597, name: Gemena
# Processing city 465 of 597, name: Haines junction
# Processing city 466 of 597, name: Fort nelson
# Processing city 467 of 597, name: Xinzhi
# Processing city 468 of 597, name: Noyon
# Processing city 469 of 597, name: Kamenka
# Processing city 470 of 597, name: Koshurnikovo
# Processing city 471 of 597, name: Zunyi
# Processing city 472 of 597, name: Zakharovo
# Processing city 473 of 597, name: Viby
# Processing city 474 of 597, name: Clarence town
# Processing city 475 of 597, name: Benguela
# Processing city 476 of 597, name: Atar
# Processing city 477 of 597, name: Westport
# Processing city 478 of 597, name: Urusha
# Processing city 479 of 597, name: Shumskiy
# Processing city 480 of 597, name: Isla mujeres
# Processing city 481 of 597, name: Ukiah
# Processing city 482 of 597, name: Upata
# Processing city 483 of 597, name: Bama
# Processing city 484 of 597, name: Nouadhibou
# Processing city 485 of 597, name: Gisborne
# Processing city 486 of 597, name: Vila
# Processing city 487 of 597, name: Iquitos
# Processing city 488 of 597, name: Laurel
# Processing city 489 of 597, name: Thunder bay
# Processing city 490 of 597, name: Mantua
# Processing city 491 of 597, name: Lakhipur
# Processing city 492 of 597, name: Deputatskiy
# Processing city 493 of 597, name: Phetchaburi
# Processing city 494 of 597, name: Vostok
# Processing city 495 of 597, name: Henties bay
# Processing city 496 of 597, name: Ust-nera
# Processing city 497 of 597, name: Bogandinskiy
# Processing city 498 of 597, name: Tupik
# Processing city 499 of 597, name: Tiznit
# The city Pokrovsk-uralskiy could not be found, skipping city...
# Processing city 501 of 597, name: Zheshart
# Processing city 502 of 597, name: Palmer
# Processing city 503 of 597, name: Pudozh
# Processing city 504 of 597, name: Basco
# The city Yanan could not be found, skipping city...
# Processing city 506 of 597, name: Homer
# Processing city 507 of 597, name: Batemans bay
# Processing city 508 of 597, name: Pyapon
# Processing city 509 of 597, name: Uruzgan
# Processing city 510 of 597, name: Aksu
# Processing city 511 of 597, name: Evensk
# Processing city 512 of 597, name: Zhenlai
# Processing city 513 of 597, name: Hofn
# Processing city 514 of 597, name: Sandur
# Processing city 515 of 597, name: Hengshui
# The city Bossembele could not be found, skipping city...
# Processing city 517 of 597, name: Sao joao da barra
# Processing city 518 of 597, name: Bud
# Processing city 519 of 597, name: Villamontes
# Processing city 520 of 597, name: Ammon
# Processing city 521 of 597, name: Morropon
# Processing city 522 of 597, name: Lubango
# Processing city 523 of 597, name: Oni
# Processing city 524 of 597, name: Quetigny
# Processing city 525 of 597, name: Marrakesh
# Processing city 526 of 597, name: Galle
# Processing city 527 of 597, name: Brae
# Processing city 528 of 597, name: Port blair
# Processing city 529 of 597, name: Gizo
# Processing city 530 of 597, name: Armidale
# Processing city 531 of 597, name: Okhotsk
# Processing city 532 of 597, name: Colac
# Processing city 533 of 597, name: Yazman
# The city Kuche could not be found, skipping city...
# Processing city 535 of 597, name: Mugla
# Processing city 536 of 597, name: Pitimbu
# Processing city 537 of 597, name: Nara
# Processing city 538 of 597, name: Rocha
# Processing city 539 of 597, name: Ekibastuz
# Processing city 540 of 597, name: Warrington
# Processing city 541 of 597, name: Vardo
# Processing city 542 of 597, name: Villa bruzual
# Processing city 543 of 597, name: Erzin
# Processing city 544 of 597, name: Axim
# Processing city 545 of 597, name: Kano
# Processing city 546 of 597, name: Lagoa
# Processing city 547 of 597, name: Maceio
# Processing city 548 of 597, name: Sinnamary
# Processing city 549 of 597, name: Vila do maio
# Processing city 550 of 597, name: Papara
# Processing city 551 of 597, name: Mitsamiouli
# Processing city 552 of 597, name: Shakawe
# Processing city 553 of 597, name: Rognan
# Processing city 554 of 597, name: Cairns
# Processing city 555 of 597, name: Pangai
# Processing city 556 of 597, name: Comodoro rivadavia
# Processing city 557 of 597, name: Chumikan
# Processing city 558 of 597, name: Alyangula
# Processing city 559 of 597, name: San juan del sur
# The city Paradwip could not be found, skipping city...
# Processing city 561 of 597, name: Antsohihy
# Processing city 562 of 597, name: Khandyga
# Processing city 563 of 597, name: Porto novo
# Processing city 564 of 597, name: Tura
# Processing city 565 of 597, name: Houma
# Processing city 566 of 597, name: Carmarthen
# Processing city 567 of 597, name: Muli
# Processing city 568 of 597, name: Wajid
# Processing city 569 of 597, name: Campbell river
# The city Mocambique could not be found, skipping city...
# Processing city 571 of 597, name: Makaryev
# Processing city 572 of 597, name: Olten
# Processing city 573 of 597, name: Horn lake
# Processing city 574 of 597, name: Sangar
# Processing city 575 of 597, name: Helena
# Processing city 576 of 597, name: Karaton
# Processing city 577 of 597, name: Primorsk
# Processing city 578 of 597, name: Barra do garcas
# Processing city 579 of 597, name: Ayan
# Processing city 580 of 597, name: Nome
# Processing city 581 of 597, name: Jutai
# Processing city 582 of 597, name: Dong hoi
# Processing city 583 of 597, name: Margate
# Processing city 584 of 597, name: Pelotas
# Processing city 585 of 597, name: Calama
# Processing city 586 of 597, name: College
# Processing city 587 of 597, name: Gilgit
# The city Ningan could not be found, skipping city...
# Processing city 589 of 597, name: Jizan
# Processing city 590 of 597, name: Vrangel
# Processing city 591 of 597, name: Pingshan
# Processing city 592 of 597, name: Kabinda
# Processing city 593 of 597, name: Tigil
# Processing city 594 of 597, name: Uirauna
# Processing city 595 of 597, name: Kudahuvadhoo
# Processing city 596 of 597, name: Mokhotlong
# The city Dinsor could not be found, skipping city...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv(os.path.join(outputDirectory,"cities.csv"))
cities_df.count()
# Out:
# Name          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
cities_df.head()
# Out:
#         Name Cloudiness Country        Date Humidity    Lat     Lng  Max Temp  \
# 0    Sakakah          0      SA  1589317465       11  29.97   40.21     78.80
# 1   Mil'kovo          0      RU  1589317466       67  54.72  158.62     41.25
# 2       Puri         20      IN  1589317466       94  19.80   85.85     80.60
# 3    Fayaoué         12      NC  1589317466       59 -20.65  166.53     73.04
# 4  Phang Nga         75      TH  1589317466       94   8.45   98.53     78.80
#
#    Wind Speed
# 0        5.82
# 1        1.68
# 2       14.05
# 3        8.46
# 4        6.93

# %%
cities_df["Humidity"] = cities_df["Humidity"].astype(float)
cities_df["Cloudiness"] = cities_df["Cloudiness"].astype(float)

cities_df.dtypes
# Out:
# Name           object
# Cloudiness    float64
# Country        object
# Date           object
# Humidity      float64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
def  plotScatter(df, yVar, title, ylabel):
    sp = df.plot(kind="scatter", x="Lat",y=yVar, s=40, c="#6d1714", 
                    edgecolors="#200404", title=title)
    sp.set(xlabel = "Latitude", ylabel = ylabel)
    sp.grid()
    return sp

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
graph = plotScatter(cities_df, "Max Temp", "City Latitude vs. Max Temperature", "Max Temperature (F)")
plt.savefig(os.path.join(outputDirectory,"scatter_lat_temp.png"))

# %% [markdown]
# The scatterplot is showing the relationship between Latitude (independient variable) and temperature (dependent variable) it's suggesting that there is a correlation between max temperature and latitude, on average cities that are closer to latitude 0 show higher temperatures than the ones that are more far away from it.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
graph = plotScatter(cities_df, "Humidity", "City Latitude vs. Humidity", "Humidity (%)")
plt.savefig(os.path.join(outputDirectory,"scatter_lat_hum.png"))

# %% [markdown]
# The scatterplot is showing  the relationship between latitude (independiente variable) and humidity (dependent variable) it's sugessting that cities near ecuator (0 latitude) usually have a high percentage of humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
graph = plotScatter(cities_df, "Cloudiness", "City Latitude vs. Cloudiness", "Cloudiness (%)")
plt.savefig(os.path.join(outputDirectory,"scatter_lat_cloud.png"))

# %% [markdown]
# The scatterplot is showing  the relationship between latitude (independiente variable) and cloudiness (dependent variable), scatterplot is not showing any clear relationship regarding both variables.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
graph = plotScatter(cities_df, "Wind Speed", "City Latitude vs. Wind Speed", "Wind Speed (mph)")
plt.savefig(os.path.join(outputDirectory,"scatter_lat_wind.png"))

# %% [markdown]
# The scatterplot is showing  the relationship between latitude (independiente variable) and wind speed (dependent variable), scatterplot shows that almost all cities are below 23 mph wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def  linearRegress(df, yVar, title, ylabel, xShow, yShow):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(df["Lat"],df[yVar])
    rgrs_values = df["Lat"] * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    graph = plotScatter(df, yVar, title, ylabel)
    plt.plot(df["Lat"],rgrs_values, '#3761c4')
    plt.annotate(line_eq,(xShow,yShow),fontsize=15,color="#3761c4")
    print(f"The r-squared is: {rvalue**2}")
    return graph

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = cities_df.loc[cities_df["Lat"] >= 0]
south_df = cities_df.loc[cities_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
graph = linearRegress(north_df, "Max Temp", "City Latitude (North) vs. Max Temperature", "Max Temperature (F)", 5,20)
plt.savefig(os.path.join(outputDirectory,"regress_north_lat_temp.png"))
# Out:
# The r-squared is: 0.8045959843386509

# %% [markdown]
# Coefficient of determination is high, which is showing a strong relationship between the  variation of temperature and latitude, in thics case movements in temperature can be explained by movements in latitude.
# In the case of Northen Hemisphere, graph is showing a negative correlation, while latitude increases, temperature decrease

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
graph = linearRegress(south_df, "Max Temp", "City Latitude (South) vs. Max Temperature", "Max Temperature (F)", -30, 40)
plt.savefig(os.path.join(outputDirectory,"regress_south_lat_temp.png"))
# Out:
# The r-squared is: 0.6620126990608167

# %% [markdown]
# Coefficient of determination is high, which is showing a strong relationship  between the variation of temperature and latitude, in thics case movements in temperature can be explained by movements in latitude.
# Grap is showing a positive correlation, while latitude increases and approaches 0, temperature also increases

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
graph = linearRegress(north_df, "Humidity", "City Latitude (North) vs. Humidity", "Humidity (%)", 45,10)
plt.savefig(os.path.join(outputDirectory,"regress_north_lat_hum.png"))
# Out:
# The r-squared is: 0.043338605112920016

# %% [markdown]
# Graph is showing a low coefficient of detemrination, which means that humidity cannot be explained by movements in latitude

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
graph = linearRegress(south_df, "Humidity", "City Latitude (South) vs. Humidity", "Humidity (%)", -25,10)
plt.savefig(os.path.join(outputDirectory,"regress_south_lat_hum.png"))
# Out:
# The r-squared is: 0.015317672669746811

# %% [markdown]
# Graph is showing a low coefficient of detemrination, which means that humidity cannot be explained by movements in latitude

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
graph = linearRegress(north_df, "Cloudiness", "City Latitude (North) vs. Cloudiness", "Cloudiness (%)", 0,7)
plt.savefig(os.path.join(outputDirectory,"regress_north_lat_cloud.png"))
# Out:
# The r-squared is: 0.016344040406177505

# %% [markdown]
# Graph is showing a low coefficient of detemrination, which means that humidity cannot be explained by movements in latitude

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
graph = linearRegress(south_df, "Cloudiness", "City Latitude (South) vs. Cloudiness", "Cloudiness (%)", -50,10)
plt.savefig(os.path.join(outputDirectory,"regress_south_lat_cloud.png"))
# Out:
# The r-squared is: 0.0020276875842479857

# %% [markdown]
# Graph is showing a low coefficient of detemrination, which means that humidity cannot be explained by movements in latitude

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
graph = linearRegress(north_df, "Wind Speed", "City Latitude (North) vs. Wind Speed", "Wind Speed (mph)", 0,50)
plt.savefig(os.path.join(outputDirectory,"regress_north_lat_wind.png"))
# Out:
# The r-squared is: 0.00012502360519970907

# %% [markdown]
# Graph is showing a low coefficient of detemrination, which means that humidity cannot be explained by movements in latitude

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
graph = linearRegress(south_df, "Wind Speed", "City Latitude (South) vs. Wind Speed", "Wind Speed (mph)", -50,30)
plt.savefig(os.path.join(outputDirectory,"regress_south_lat_wind.png"))
# Out:
# The r-squared is: 0.024468889757512133

# %% [markdown]
# Graph is showing a low coefficient of detemrination, which means that humidity cannot be explained by movements in latitude
